# %%
# %pip install langchain-community
# Out:
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 769.0 kB/s eta 0:00:03
#    -------- ------------------------------- 0.5/2.5 MB 769.0 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 763.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 763.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 763.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 763.6 kB/s eta 0:00:03
#    ------------ --------------------------- 0.8/2.5 MB 763.6 kB/s eta 0:00:03
#    ---------------- ----------------------- 1.0/2.5 MB 421.6 kB/s eta 0:00:04
# ...

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader = TextLoader("../data/nvidia_news_1.txt")
data = loader.load()
data[0]
# Out:
# Document(metadata={'source': '../data/nvidia_news_1.txt'}, page_content='NVIDIA announces new AI chip lineup for 2026.\nThe company reported strong Q4 earnings with revenue growth of 28%.\nNVIDIA partners with major cloud providers to accelerate AI adoption.\nStock prices surged following the announcement of the new GPU series.\nAnalysts predict continued growth for NVIDIA in the AI and gaming markets.\n')

# %%
# Out:
# 0.4.1

# %%
# Out:
# ['nvidia_news_1.txt']
